# %% [markdown]
# # Problem 966 - Triangle Circle Intersection
# Let $I(a, b, c)$ be the largest possible area of intersection between a triangle of side lengths $a, b, c$ and a circle which has the same area as the triangle.
# For example $I(3, 4, 5) \approx 4.593049$ and $I(3, 4, 6) \approx 3.552564$.
#
# Find the sum of $I(a, b, c)$ for integers $a, b, c$ such that $1 \le a \le b \le c \lt a + b$ and $a + b + c \le 200$.
#
# Give your answer rounded to two digits after the decimal point.
# ## Solution.

# %%
from math import sqrt, pi, gcd
import math
import numpy as np
from scipy.optimize import minimize

# %%
def triangle_area(a, b, c):
    p  = (a+b+c)/2
    return sqrt(p*(p-a)*(p-b)*(p-c))

def radius(a, b, c):
    A = triangle_area(a, b, c)
    return sqrt(A/pi)

# %%
def d(X, Y):
    '''
    Distace between X and Y
    '''
    return sqrt((X[0]-Y[0])**2 + (X[1]-Y[1])**2)

def d_l(A, X, Y):
    '''
    Distance of point A from the infinite line passing through X and Y
    '''
    x0, y0 = A
    x1, y1 = X
    x2, y2 = Y

    dx = x2 - x1
    dy = y2 - y1

    num = abs(dy * x0 - dx * y0 + x2*y1 - y2*x1)
    den = sqrt(dx*dx + dy*dy)

    return num / den

# %%
def intersection_line_circle(A, B, O, R):
    x_a, y_a = A
    x_b, y_b = B
    x_o, y_o = O

    x_a -= x_o
    x_b -= x_o
    y_a -= y_o
    y_b -= y_o

    # solve |A + t(B-A)| = R
    dx = x_b - x_a
    dy = y_b - y_a
    a = dx**2 + dy**2
    b = 2*dx*x_a + 2*dy*y_a
    c = x_a**2 + y_a**2 - R**2

    delta = b**2 - 4*a*c

    if delta < 0:
        return []
    
    sqrt_delta = sqrt(delta)

    t1 = (-b - sqrt_delta) / (2*a)
    t2 = (-b + sqrt_delta) / (2*a)

    points = []
    for t in (t1, t2):
        if 0 < t < 1:     # intersection lies ON segment AB
            x = x_a + t*dx + x_o
            y = y_a + t*dy + y_o
            if (x,y) not in points:
                points.append((x, y))

    return sorted(points, key=lambda P: (P[0]-A[0])**2 + (P[1]-A[1])**2)

# %%
def arc_area(P, Q, O, R):
    x_p, y_p = P
    x_q, y_q = Q
    x_o, y_o = O
    
    px, py = x_p - x_o, y_p - y_o
    qx, qy = x_q - x_o, y_q - y_o

    cross = px*qy - py*qx
    dot   = px*qx + py*qy

    theta = math.atan2(cross, dot)

    return abs(0.5 * R**2 * theta)


def triangle_area_points(A, B, C):
    x1, y1 = A
    x2, y2 = B
    x3, y3 = C
    return 0.5 * abs(x1*(y2-y3) + x2*(y3-y1) + x3*(y1-y2))

# %%
def triangle_cap_circle_area(A, B, C, O, R):
    # Collect points along edges and circle intersections
    vertices = [A]

    pts = intersection_line_circle(A, B, O, R)
    vertices += pts
    vertices.append(B)

    pts = intersection_line_circle(B, C, O, R)
    vertices += pts
    vertices.append(C)

    pts = intersection_line_circle(C, A, O, R)
    vertices += pts
    vertices.append(A)

    # Sum the areas
    area = 0.0
    n = len(vertices)
    for i in range(n):
        P = vertices[i]
        Q = vertices[(i+1)%n]

        # midpoint test: inside circle?
        mx = 0.5*(P[0]+Q[0])
        my = 0.5*(P[1]+Q[1])
        inside = ((mx-O[0])**2 + (my-O[1])**2) <= R**2 + 1e-12

        if inside:
            area += triangle_area_points(O, P, Q)
        else:
            area += arc_area(P, Q, O, R)

    return abs(area)

# %%
def intersection_area(a, b, c, x, y):
    R = radius(a, b, c)
    O = (x, y)

    # Find triangle coordinates
    x_a = (a**2 - b**2 + c**2)/(2*a)
    y_a = sqrt(c**2 - x_a**2)

    A = (x_a, y_a)
    B = (0, 0)
    C = (a, 0)

    return triangle_cap_circle_area(A, B, C, O, R)

# %%
def I(a, b, c, intersection_area_func):
    x_a = (a**2 - b**2 + c**2)/(2*a)
    y_a = sqrt(c**2 - x_a**2)
    A = (x_a, y_a)
    B = (0, 0)
    C = (a, 0)

    x0 = np.array([a/2, 0])
    res = minimize(lambda p: -intersection_area_func(a, b, c, p[0], p[1]),
                   x0, method='SLSQP', options={'ftol':1e-9})
    
    return abs(res.fun), res.x

# %%
I(3,4,5, intersection_area)
# Out:
# (np.float64(4.593049357083796), array([1.94009318, 1.21139371]))

# %%
I(3,4,6, intersection_area)
# Out:
# (np.float64(3.552563962513816), array([2.45094032, 1.13599752]))

# %%
ans = 0
counter = 0

for a in range(1, 201):
    b_max = min(200 - a - 1, 200) 
    for b in range(a, b_max + 1):
        c_max = min(a + b - 1, 200 - a - b)
        for c in range(b, c_max + 1):
            ans += I(a, b, c, intersection_area)[0]
            counter += 1 
            if counter % 1000 == 0:
                print(f"Processed {counter} triples, current sum: {ans}")

ans
# Out:
# Processed 1000 triples, current sum: 21342.802492632658
# Processed 2000 triples, current sum: 70182.96239578808
# Processed 3000 triples, current sum: 136203.33695712962
# Processed 4000 triples, current sum: 230863.31677308315
# Processed 5000 triples, current sum: 334051.8252749324
# Processed 6000 triples, current sum: 454326.38334049704
# Processed 7000 triples, current sum: 593331.6980532687
# Processed 8000 triples, current sum: 750597.4397397502
# Processed 9000 triples, current sum: 926889.6738817508
# Processed 10000 triples, current sum: 1125086.7500340699
# Processed 11000 triples, current sum: 1323770.4168020736
# Processed 12000 triples, current sum: 1529106.7176806643
# Processed 13000 triples, current sum: 1753984.479012823
# Processed 14000 triples, current sum: 2002563.9750263782
# Processed 15000 triples, current sum: 2284076.442440814
# Processed 16000 triples, current sum: 2555699.864770223
# Processed 17000 triples, current sum: 2827485.9671445563
# Processed 18000 triples, current sum: 3132857.1624600985
# Processed 19000 triples, current sum: 3483796.748049369
# Processed 20000 triples, current sum: 3794847.2650040677
# Processed 21000 triples, current sum: 4127525.8699302073
# Processed 22000 triples, current sum: 4508722.4250909155
# Processed 23000 triples, current sum: 4892749.081432738
# Processed 24000 triples, current sum: 5258111.328088512
# Processed 25000 triples, current sum: 5672961.422172618
# Processed 26000 triples, current sum: 6130450.382468284
# Processed 27000 triples, current sum: 6519385.137205795
# Processed 28000 triples, current sum: 6973144.195229605
# Processed 29000 triples, current sum: 7490971.3286342025
# Processed 30000 triples, current sum: 7919105.95911647
# Processed 31000 triples, current sum: 8410652.963828865
# Processed 32000 triples, current sum: 8964758.806991851
# Processed 33000 triples, current sum: 9457798.377868766
# Processed 34000 triples, current sum: 9987490.079095202
# Processed 35000 triples, current sum: 10577536.45548203
# Processed 36000 triples, current sum: 11153573.842663668
# Processed 37000 triples, current sum: 11716788.47189307
# Processed 38000 triples, current sum: 12336993.180852888
# Processed 39000 triples, current sum: 13012308.174478348
# Processed 40000 triples, current sum: 13611776.993085884
# Processed 41000 triples, current sum: 14263825.687254284
# Processed 42000 triples, current sum: 14964288.198915113
# Processed 43000 triples, current sum: 15700503.317724101
# Processed 44000 triples, current sum: 16430254.21224819
# Processed 45000 triples, current sum: 17132764.575998154
# Processed 46000 triples, current sum: 17896231.818922408
# Processed 47000 triples, current sum: 18696005.6540929
# Processed 48000 triples, current sum: 19524451.34932336
# Processed 49000 triples, current sum: 20374848.12455231
# Processed 50000 triples, current sum: 21253390.387887776
# Processed 51000 triples, current sum: 22165809.06735785
# Processed 52000 triples, current sum: 23135208.402359832
# Processed 53000 triples, current sum: 24187550.975640986
# Processed 54000 triples, current sum: 25223204.766615253
# Processed 55000 triples, current sum: 26384481.032165747
# Processed 56000 triples, current sum: 27644369.33834565
# Processed 57000 triples, current sum: 29006384.32421913
# np.float64(29337152.09138967)

# %% [markdown]
# Answer : $29,337,152.09$
