# %% [markdown]
# # Problem 18i
# Let $p$ be a prime, and $f(x)=x**3−3x+4$ and define $R(p)$ as follows:
# $$R(p)=\prod_{x=0}^{p-1}f(x) \mod p.$$
#
# For example,$R(11)=0$, $R(29)=13$. Find the sum of $R(p)$ over all primes $p$ with $10**9<p<10**9+10**8$.
#
# ## Solution.
